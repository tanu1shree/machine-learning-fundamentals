# %%
import pandas as pd

# %%
df = pd.read_csv("hr_analytics.xls")
df
# Out:
#      Age  Gender Department  MonthlyIncome  TotalWorkingYears  YearsAtCompany  \
# 0     50  Female         HR           4753                 14               8
# 1     36    Male        R&D          13123                  3               7
# 2     29    Male         HR          19376                 16              15
# 3     42    Male         HR           9588                 19              14
# 4     40    Male        R&D           9304                 18               8
# ..   ...     ...        ...            ...                ...             ...
# 995   34  Female      Sales           7986                  2               5
# 996   51  Female      Sales           4481                 26              12
# 997   44    Male         HR           6731                 27               6
# 998   40  Female      Sales          19835                 27               9
# 999   53  Female         HR          13758                 15               1
#
# ...

# %% [markdown]
# 1. How many rows and columns in the dataset?

# %%
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# 2. What are the data types of each column?

# %%
df.dtypes
# Out:
# Age                   int64
# Gender               object
# Department           object
# MonthlyIncome         int64
# TotalWorkingYears     int64
# YearsAtCompany        int64
# JobSatisfaction       int64
# WorkLifeBalance       int64
# OverTime             object
# Attrition            object
# dtype: object

# %% [markdown]
# 3. Any missing values?

# %%
df.isna()
# Out:
#        Age  Gender  Department  MonthlyIncome  TotalWorkingYears  \
# 0    False   False       False          False              False
# 1    False   False       False          False              False
# 2    False   False       False          False              False
# 3    False   False       False          False              False
# 4    False   False       False          False              False
# ..     ...     ...         ...            ...                ...
# 995  False   False       False          False              False
# 996  False   False       False          False              False
# 997  False   False       False          False              False
# 998  False   False       False          False              False
# 999  False   False       False          False              False
#
#      YearsAtCompany  JobSatisfaction  WorkLifeBalance  OverTime  Attrition
# 0             False            False            False     False      False
# ...

# %%
df.isna().sum()
# Out:
# Age                  0
# Gender               0
# Department           0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# JobSatisfaction      0
# WorkLifeBalance      0
# OverTime             0
# Attrition            0
# dtype: int64

# %% [markdown]
# 4. Any duplicate values?

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 5. Number of Employees

# %%
len(df)
# Out:
# 1000

# %% [markdown]
# 6. Number of Departments

# %%
df["Department"].nunique()
# Out:
# 3

# %% [markdown]
# 7. Display all Departments

# %%
df["Department"].unique()
# Out:
# array(['HR', 'R&D', 'Sales'], dtype=object)

# %% [markdown]
# 8. Average Employee Age

# %%
sum(df["Age"]) / len(df["Age"])
# Out:
# 40.947

# %% [markdown]
# 9. Minimum and Maximum Employees

# %%
df["Age"].min()
# Out:
# 22

# %%
df["Age"].max()
# Out:
# 59

# %% [markdown]
# 10. Gender Distribution of Employees

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      504
# Female    496
# Name: count, dtype: int64

# %% [markdown]
# 11. Number of Employees in each department

# %%
df["Department"].value_counts()
# Out:
# Department
# HR       352
# Sales    343
# R&D      305
# Name: count, dtype: int64

# %% [markdown]
# 12. How many employees have more than 10 years of experience - total working years?

# %%
len(df[df["TotalWorkingYears"] > 10])
# Out:
# 720

# %% [markdown]
# 13. How many employees have been with the company for more than 5 years?

# %%
len(df[df["YearsAtCompany"] > 5])
# Out:
# 752

# %% [markdown]
# 14. Average monthly income in each department

# %%
df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# HR       11604.042614
# R&D      11461.272131
# Sales    11417.247813
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# 15. How many employees have left the company in each department?

# %%
df[df["Attrition"] == "Yes"]["Department"].value_counts()
# Out:
# Department
# R&D      74
# HR       70
# Sales    59
# Name: count, dtype: int64
