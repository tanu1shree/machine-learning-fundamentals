# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('house_price.csv')
df.head()
# Out:
#    House Size  Bedrooms  Age of House  House Price
# 0        1500         3            10       350000
# 1        1800         3             8       400000
# 2        2000         4             5       450000
# 3        2200         4             2       475000
# 4        2500         5            15       525000

# %%
X = df[['House Size', 'Bedrooms', 'Age of House']]
Y = df['House Price']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([ 958198.91326438, 3084757.95178209, 2213923.0591368 ,
#        3676539.75229267, 1145827.56632132, 3989268.46066852,
#        1827657.81346492, 1706685.73548026, 2419439.6139755 ,
#        1275055.59897449])

# %%
r2_score_value = r2_score(Y_test, Y_pred)
r2_score_value
print(f"R-squared Score: {r2_score_value}")
# Out:
# R-squared Score: 0.9987416757120748

# %%
plt.scatter(Y_test, Y_pred, color='blue', label='Actual vs Predicted')
plt.xlabel('Actual House Price ($)')
plt.ylabel('Predicted House Price ($)')
plt.title('Actual vs Predicted House Price')
plt.legend()
plt.show()

# %%
user_House_Size = int(input("Enter House Size: "))
user_Bedrooms = int(input("Enter Number of Bedrooms: "))
user_Age = int(input("Enter Age of House: "))
user_df = pd.DataFrame([[user_House_Size, user_Bedrooms, user_Age]], columns=['House Size', 'Bedrooms', 'Age of House'])
predicted_price = model.predict(user_df)
print(f"The predicted House Price is: ${predicted_price[0]:.2f}")
# Out:
# Enter House Size:  1800
# Enter Number of Bedrooms:  3
# Enter Age of House:  10
# The predicted House Price is: $323792.97
